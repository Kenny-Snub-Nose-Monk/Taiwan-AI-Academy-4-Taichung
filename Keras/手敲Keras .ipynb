# %%
import tensorflow.keras as keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


import matplotlib.pyplot as plt
import os

# %%
# 超參數設定
batch_size =  128 #訓練完128張照片就更新一次權重
num_classes = 10 #照片分類總共分為10類
epochs = 20 #全部的相片跑100次

#儲存model
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

#資料載入
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 將目標值轉為 one hot 型式
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

#建立模型
model = Sequential()
model.add(Conv2D(64, (3,3), padding = 'same',
                input_shape = x_train.shape[1:]))

print(x_train.shape[1:])

model.add(Activation('relu'))
model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

print(model.summary())

#選擇優化器
opt = keras.optimizers.Adam()

#編輯模型
model.compile(loss = 'categorical_crossentropy',
             optimizer = opt,
             metrics=['accuracy'])
             
#資料歸一化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.
x_test /= 255.

print('Using real-time data augmentation.')

#數據再造 : 對圖片做旋轉、平移、模糊化...等操作
datagen = ImageDataGenerator(
    rotation_range = 30,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    vertical_flip = False)

#儲存 模型與權重
if not os.path.isdir(save_dir):
    os.makeidrs(save_dir)
    
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)

#設定早停功能,避免資源浪費
earlystop = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 1)#為什麼要有verbose


#訓練模型
model_history = model.fit_generator(datagen.flow(x_train, y_train
                                                , batch_size = batch_size),
                                    epochs = epochs,
                                    validation_data = (x_test, y_test), #什麼意思?
                                    callbacks = [earlystop])
#入載模型
print("Loading trained model")
model = load_model(model_path)

#評估模型
scores = model.evaluate(x_test, y_test, verbose = 1)
print("Test Loss", scores[0])
print("Test accuracy", scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# (32, 32, 3)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_18 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 30, 30, 128)       73856
# _________________________________________________________________
# activation_19 (Activation)   (None, 30, 30, 128)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 15, 15, 64)        73792
# _________________________________________________________________
# activation_20 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# activation_21 (Activation)   (None, 13, 13, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# activation_22 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_23 (Activation)   (None, 10)                0
# =================================================================
# Total params: 2,588,234
# Trainable params: 2,588,234
# Non-trainable params: 0
# _________________________________________________________________
# None
# Using real-time data augmentation.
# Epoch 1/20
# 391/391 [==============================] - 26s 67ms/step - loss: 1.7307 - accuracy: 0.3607 - val_loss: 1.2963 - val_accuracy: 0.5311
# Epoch 2/20
# 391/391 [==============================] - 26s 67ms/step - loss: 1.3720 - accuracy: 0.5053 - val_loss: 1.2147 - val_accuracy: 0.5733
# Epoch 3/20
# 391/391 [==============================] - 26s 66ms/step - loss: 1.2432 - accuracy: 0.5586 - val_loss: 1.0697 - val_accuracy: 0.6254
# Epoch 4/20
# 391/391 [==============================] - 25s 65ms/step - loss: 1.1361 - accuracy: 0.5958 - val_loss: 1.0496 - val_accuracy: 0.6279
# Epoch 5/20
# 391/391 [==============================] - 26s 67ms/step - loss: 1.0730 - accuracy: 0.6183 - val_loss: 0.9589 - val_accuracy: 0.6672
# Epoch 6/20
# 391/391 [==============================] - 26s 66ms/step - loss: 1.0214 - accuracy: 0.6385 - val_loss: 0.9269 - val_accuracy: 0.6815
# Epoch 7/20
# 391/391 [==============================] - 26s 66ms/step - loss: 0.9811 - accuracy: 0.6560 - val_loss: 0.9228 - val_accuracy: 0.6826
# Epoch 8/20
# 391/391 [==============================] - 26s 66ms/step - loss: 0.9491 - accuracy: 0.6646 - val_loss: 0.7539 - val_accuracy: 0.7422
# Epoch 9/20
# 391/391 [==============================] - 26s 67ms/step - loss: 0.9222 - accuracy: 0.6733 - val_loss: 0.7924 - val_accuracy: 0.7259
# Epoch 10/20
# 391/391 [==============================] - 26s 66ms/step - loss: 0.8891 - accuracy: 0.6887 - val_loss: 0.7762 - val_accuracy: 0.7314
# Epoch 11/20
# 391/391 [==============================] - 26s 66ms/step - loss: 0.8722 - accuracy: 0.6945 - val_loss: 0.7804 - val_accuracy: 0.7331
# Epoch 12/20
# 391/391 [==============================] - 25s 63ms/step - loss: 0.8562 - accuracy: 0.7022 - val_loss: 0.7314 - val_accuracy: 0.7494
# Epoch 13/20
# 391/391 [==============================] - 24s 63ms/step - loss: 0.8358 - accuracy: 0.7100 - val_loss: 0.7539 - val_accuracy: 0.7425
# Epoch 14/20
# 391/391 [==============================] - 25s 63ms/step - loss: 0.8152 - accuracy: 0.7152 - val_loss: 0.7952 - val_accuracy: 0.7375
# Epoch 15/20
# 391/391 [==============================] - 24s 62ms/step - loss: 0.8062 - accuracy: 0.7202 - val_loss: 0.7634 - val_accuracy: 0.7427
# Epoch 16/20
# 391/391 [==============================] - 25s 63ms/step - loss: 0.7974 - accuracy: 0.7211 - val_loss: 0.6660 - val_accuracy: 0.7774
# Epoch 17/20
# 391/391 [==============================] - 25s 63ms/step - loss: 0.7840 - accuracy: 0.7258 - val_loss: 0.7059 - val_accuracy: 0.7594
# Epoch 18/20
# 391/391 [==============================] - 25s 64ms/step - loss: 0.7685 - accuracy: 0.7319 - val_loss: 0.6876 - val_accuracy: 0.7637
# Epoch 19/20
# 391/391 [==============================] - 24s 62ms/step - loss: 0.7687 - accuracy: 0.7311 - val_loss: 0.6902 - val_accuracy: 0.7638
# Epoch 20/20
# 391/391 [==============================] - 25s 64ms/step - loss: 0.7609 - accuracy: 0.7357 - val_loss: 0.6569 - val_accuracy: 0.7760
# Loading trained model
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test Loss 0.8156274256706237
# Test accuracy 0.7139
